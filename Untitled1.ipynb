# %%
import numpy as np
import pandas as pd
import os

# %%
df_path = os.path.join(os.getcwd(), 'data_test.csv')
df = pd.read_csv(df_path)

# %%
df
# Out:
#        SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0          100001     NaN            1             0                0
# 1          100005     NaN            0             0                0
# 2          100013     NaN            0             1                0
# 3          100028     NaN            1             0                0
# 4          100038     NaN            0             1                1
# ...           ...     ...          ...           ...              ...
# 48739      456221     NaN            1             0                0
# 48740      456222     NaN            1             0                1
# 48741      456223     NaN            1             1                0
# 48742      456224     NaN            0             0                1
# 48743      456250     NaN            1             1                1
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# ...

# %%
df_path = os.path.join(os.getcwd(), 'info_clients.csv')
data = pd.read_csv(df_path)

# %%
data
# Out:
#         SK_ID_CURR  DAYS_BIRTH CODE_GENDER  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0           100002       -9461           M             0              1.0
# 1           100003      -16765           F             0              2.0
# 2           100004      -19046           M             0              1.0
# 3           100006      -19005           F             0              2.0
# 4           100007      -19932           M             0              1.0
# ...            ...         ...         ...           ...              ...
# 356250      456221      -19970           F             0              1.0
# 356251      456222      -11186           F             2              4.0
# 356252      456223      -15922           F             1              3.0
# 356253      456224      -13968           M             0              2.0
# 356254      456250      -13962           F             0              2.0
#
#        FLAG_OWN_CAR FLAG_OWN_REALTY  REGION_POPULATION_RELATIVE  \
# ...

# %%
# Filtrer df1 en fonction des valeurs de df2
dat = data[data['SK_ID_CURR'].isin(df['SK_ID_CURR'])]
dat.to_csv("./info_clients.csv", index=False)
